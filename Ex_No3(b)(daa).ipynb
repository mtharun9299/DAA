# %% [markdown]
# <a href="https://colab.research.google.com/github/mtharun9299/DAA/blob/main/Ex_No3(b)(daa).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- New Graph Definition for 6 Cities ---
n_new = 6
edges_new = [
    (4, 0, 1), # A-B:4
    (2, 0, 2), # A-C:2
    (5, 1, 2), # B-C:5
    (10, 1, 3), # B-D:10
    (3, 2, 4), # C-E:3
    (7, 3, 4), # D-E:7
    (8, 3, 5), # D-F:8
    (6, 4, 5)  # E-F:6
]

print('=== Kruskal\'s MST for 6-City Network ===')
k_mst_new, k_cost_new = kruskal(n_new, edges_new[:])

# Map numerical indices back to city names for better readability
cities = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E', 5: 'F'}

for u, v, w in k_mst_new:
    print(f'  Edge ({cities[u]} - {cities[v]})  Weight: {w}')
print(f'  Total MST Cost: {k_cost_new}')
# Out:
# === Kruskal's MST for 6-City Network ===
#   Edge (A - C)  Weight: 2
#   Edge (C - E)  Weight: 3
#   Edge (A - B)  Weight: 4
#   Edge (E - F)  Weight: 6
#   Edge (D - E)  Weight: 7
#   Total MST Cost: 22
