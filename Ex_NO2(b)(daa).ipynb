# %% [markdown]
# <a href="https://colab.research.google.com/github/mtharun9299/DAA/blob/main/Ex_NO2(b)(daa).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
new_text = 'AABCAABXAAAZ'
new_pattern = 'AABXAA'

print(f'New Text:    {new_text}')
print(f'New Pattern: {new_pattern}')

matches_kmp, comparisons_kmp = kmp_search(new_text, new_pattern)

print(f'\nKMP    -> Matches at: {matches_kmp}, Comparisons: {comparisons_kmp}')
# Out:
# New Text:    AABCAABXAAAZ
# New Pattern: AABXAA
#
# KMP    -> Matches at: [4], Comparisons: 14
